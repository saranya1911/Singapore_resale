# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('combined.csv')
df
# Out:
#         latitude   longitude blk_no            road_name  postal_code  \
# 0       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 1       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 2       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 3       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 4       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# ...          ...         ...    ...                  ...          ...
# 206096  1.362410  103.935601   605A   TAMPINES STREET 61       521605
# 206097  1.361872  103.935562   605C   TAMPINES STREET 61       523605
# 206098  1.332964  103.855447    263       TOA PAYOH EAST       310263
# 206099  1.332465  103.855238    264       TOA PAYOH EAST       310264
# 206100  1.424389  103.852083   469B     YISHUN STREET 43       762469
#
#                      address      cbd_dist  min_dist_mrt    month        town  \
# 0       174 ANG MO KIO AVE 4  10296.855747   1098.780832  2015-01  ANG MO KIO
# 1       174 ANG MO KIO AVE 4  10296.855747   1098.780832  2015-12  ANG MO KIO
# 2       174 ANG MO KIO AVE 4  10296.855747   1098.780832  2016-05  ANG MO KIO
# 3       174 ANG MO KIO AVE 4  10296.855747   1098.780832  2016-06  ANG MO KIO
# 4       174 ANG MO KIO AVE 4  10296.855747   1098.780832  2016-11  ANG MO KIO
# ...                      ...           ...           ...      ...         ...
# 206096   605A TAMPINES ST 61  12849.881638   1894.590564  2023-12    TAMPINES
# 206097   605C TAMPINES ST 61  12806.244884   1836.752185  2023-12    TAMPINES
# 206098    263 TOA PAYOH EAST   5543.994635    876.804870  2023-12   TOA PAYOH
# 206099    264 TOA PAYOH EAST   5487.060026    852.628695  2023-12   TOA PAYOH
# 206100     469B YISHUN ST 43  15634.294384   1981.003601  2023-12      YISHUN
#
#        flat_type block       street_name storey_range  floor_area_sqm  \
# 0         3 ROOM   174  ANG MO KIO AVE 4     07 TO 09            60.0
# 1         3 ROOM   174  ANG MO KIO AVE 4     10 TO 12            60.0
# 2         3 ROOM   174  ANG MO KIO AVE 4     04 TO 06            69.0
# 3         2 ROOM   174  ANG MO KIO AVE 4     07 TO 09            45.0
# 4         3 ROOM   174  ANG MO KIO AVE 4     04 TO 06            61.0
# ...          ...   ...               ...          ...             ...
# 206096    4 ROOM  605A    TAMPINES ST 61     10 TO 12            92.0
# 206097    4 ROOM  605C    TAMPINES ST 61     13 TO 15            92.0
# 206098    4 ROOM   263    TOA PAYOH EAST     07 TO 09            93.0
# 206099    4 ROOM   264    TOA PAYOH EAST     22 TO 24            93.0
# 206100    2 ROOM  469B      YISHUN ST 43     10 TO 12            47.0
#
#        flat_model  lease_commence_date  resale_price     remaining_lease  \
# 0        Improved                 1986      255000.0                  70
# 1        Improved                 1986      275000.0                  69
# 2        Improved                 1986      310000.0                  68
# 3        Improved                 1986      253000.0                  68
# 4        Improved                 1986      290000.0                  68
# ...           ...                  ...           ...                 ...
# 206096    Model A                 2020      718000.0  95 years 02 months
# 206097    Model A                 2020      745000.0  95 years 02 months
# 206098    Model A                 2019      888000.0   95 years 01 month
# 206099    Model A                 2019      950000.0   95 years 01 month
# 206100    Model A                 2019      346000.0            95 years
#
#         lease_remain_years
# 0                       62
# 1                       62
# 2                       62
# 3                       62
# 4                       62
# ...                    ...
# 206096                  96
# 206097                  96
# 206098                  95
# 206099                  95
# 206100                  95
#
# [206101 rows x 20 columns]

# %%
df.dtypes
# Out:
# latitude               float64
# longitude              float64
# blk_no                  object
# road_name               object
# postal_code              int64
# address                 object
# cbd_dist               float64
# min_dist_mrt           float64
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# lease_remain_years       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# latitude               0
# longitude              0
# blk_no                 0
# road_name              0
# postal_code            0
# address                0
# cbd_dist               0
# min_dist_mrt           0
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# lease_remain_years     0
# dtype: int64

# %%
import statistics

def get_median(x):
    split_list = x.split(' TO ')
    float_list = [float(i) for i in split_list]
    median = statistics.median(float_list)
    return median

df['storey_median'] = df['storey_range'].apply(lambda x: get_median(x))
df
# Out:
#         latitude   longitude blk_no            road_name  postal_code  \
# 0       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 1       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 2       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 3       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 4       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# ...          ...         ...    ...                  ...          ...
# 206096  1.362410  103.935601   605A   TAMPINES STREET 61       521605
# 206097  1.361872  103.935562   605C   TAMPINES STREET 61       523605
# 206098  1.332964  103.855447    263       TOA PAYOH EAST       310263
# 206099  1.332465  103.855238    264       TOA PAYOH EAST       310264
# 206100  1.424389  103.852083   469B     YISHUN STREET 43       762469
#
#                      address      cbd_dist  min_dist_mrt    month        town  \
# 0       174 ANG MO KIO AVE 4  10296.855747   1098.780832  2015-01  ANG MO KIO
# 1       174 ANG MO KIO AVE 4  10296.855747   1098.780832  2015-12  ANG MO KIO
# 2       174 ANG MO KIO AVE 4  10296.855747   1098.780832  2016-05  ANG MO KIO
# 3       174 ANG MO KIO AVE 4  10296.855747   1098.780832  2016-06  ANG MO KIO
# 4       174 ANG MO KIO AVE 4  10296.855747   1098.780832  2016-11  ANG MO KIO
# ...                      ...           ...           ...      ...         ...
# 206096   605A TAMPINES ST 61  12849.881638   1894.590564  2023-12    TAMPINES
# 206097   605C TAMPINES ST 61  12806.244884   1836.752185  2023-12    TAMPINES
# 206098    263 TOA PAYOH EAST   5543.994635    876.804870  2023-12   TOA PAYOH
# 206099    264 TOA PAYOH EAST   5487.060026    852.628695  2023-12   TOA PAYOH
# 206100     469B YISHUN ST 43  15634.294384   1981.003601  2023-12      YISHUN
#
#         ... block       street_name storey_range floor_area_sqm  flat_model  \
# 0       ...   174  ANG MO KIO AVE 4     07 TO 09           60.0    Improved
# 1       ...   174  ANG MO KIO AVE 4     10 TO 12           60.0    Improved
# 2       ...   174  ANG MO KIO AVE 4     04 TO 06           69.0    Improved
# 3       ...   174  ANG MO KIO AVE 4     07 TO 09           45.0    Improved
# 4       ...   174  ANG MO KIO AVE 4     04 TO 06           61.0    Improved
# ...     ...   ...               ...          ...            ...         ...
# 206096  ...  605A    TAMPINES ST 61     10 TO 12           92.0     Model A
# 206097  ...  605C    TAMPINES ST 61     13 TO 15           92.0     Model A
# 206098  ...   263    TOA PAYOH EAST     07 TO 09           93.0     Model A
# 206099  ...   264    TOA PAYOH EAST     22 TO 24           93.0     Model A
# 206100  ...  469B      YISHUN ST 43     10 TO 12           47.0     Model A
#
#        lease_commence_date  resale_price     remaining_lease  \
# 0                     1986      255000.0                  70
# 1                     1986      275000.0                  69
# 2                     1986      310000.0                  68
# 3                     1986      253000.0                  68
# 4                     1986      290000.0                  68
# ...                    ...           ...                 ...
# 206096                2020      718000.0  95 years 02 months
# 206097                2020      745000.0  95 years 02 months
# 206098                2019      888000.0   95 years 01 month
# 206099                2019      950000.0   95 years 01 month
# 206100                2019      346000.0            95 years
#
#        lease_remain_years  storey_median
# 0                      62            8.0
# 1                      62           11.0
# 2                      62            5.0
# 3                      62            8.0
# 4                      62            5.0
# ...                   ...            ...
# 206096                 96           11.0
# 206097                 96           14.0
# 206098                 95            8.0
# 206099                 95           23.0
# 206100                 95           11.0
#
# [206101 rows x 21 columns]

# %%
scope_df = df[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']]
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0       10296.855747   1098.780832            60.0                  62
# 1       10296.855747   1098.780832            60.0                  62
# 2       10296.855747   1098.780832            69.0                  62
# 3       10296.855747   1098.780832            45.0                  62
# 4       10296.855747   1098.780832            61.0                  62
# ...              ...           ...             ...                 ...
# 206096  12849.881638   1894.590564            92.0                  96
# 206097  12806.244884   1836.752185            92.0                  96
# 206098   5543.994635    876.804870            93.0                  95
# 206099   5487.060026    852.628695            93.0                  95
# 206100  15634.294384   1981.003601            47.0                  95
#
#         storey_median  resale_price
# 0                 8.0      255000.0
# 1                11.0      275000.0
# 2                 5.0      310000.0
# 3                 8.0      253000.0
# 4                 5.0      290000.0
# ...               ...           ...
# 206096           11.0      718000.0
# 206097           14.0      745000.0
# 206098            8.0      888000.0
# 206099           23.0      950000.0
# 206100           11.0      346000.0
#
# [206101 rows x 6 columns]

# %%
scope_df = scope_df.drop_duplicates()
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0       10296.855747   1098.780832            60.0                  62
# 1       10296.855747   1098.780832            60.0                  62
# 2       10296.855747   1098.780832            69.0                  62
# 3       10296.855747   1098.780832            45.0                  62
# 4       10296.855747   1098.780832            61.0                  62
# ...              ...           ...             ...                 ...
# 206096  12849.881638   1894.590564            92.0                  96
# 206097  12806.244884   1836.752185            92.0                  96
# 206098   5543.994635    876.804870            93.0                  95
# 206099   5487.060026    852.628695            93.0                  95
# 206100  15634.294384   1981.003601            47.0                  95
#
#         storey_median  resale_price
# 0                 8.0      255000.0
# 1                11.0      275000.0
# 2                 5.0      310000.0
# 3                 8.0      253000.0
# 4                 5.0      290000.0
# ...               ...           ...
# 206096           11.0      718000.0
# 206097           14.0      745000.0
# 206098            8.0      888000.0
# 206099           23.0      950000.0
# 206100           11.0      346000.0
#
# [199735 rows x 6 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns(continuous variables) for finding skewness
col = ['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']

for i in col:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')
    plt.xlabel(i)
    plt.show()

# %%
df1 = scope_df

# %%
df1['floor_area_sqm'] = np.log(df1['floor_area_sqm'])
sns.boxplot(x='floor_area_sqm', data=df1)
plt.show()

df1['storey_median'] = np.log(df1['storey_median'])
sns.boxplot(x='storey_median', data=df1)
plt.show()

df1['resale_price'] = np.log(df1['resale_price'])
sns.boxplot(x='resale_price', data=df1)
plt.show()

# %%
df1.dtypes
# Out:
# cbd_dist              float64
# min_dist_mrt          float64
# floor_area_sqm        float64
# lease_remain_years      int64
# storey_median         float64
# resale_price          float64
# dtype: object

# %%
import seaborn as sns

corrMatrix = df1.corr()
plt.figure(figsize=(15, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %%
from sklearn.preprocessing import StandardScaler

X=df1[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median']]
y=df1['resale_price']

# Normalizing the encoded data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
test_dataframe = pd.DataFrame(X)
test_dataframe
# Out:
#                0         1         2         3         4
# 0      -0.487059  0.587379 -1.773987 -0.667043  0.212345
# 1      -0.487059  0.587379 -1.773987 -0.667043  0.655533
# 2      -0.487059  0.587379 -1.228248 -0.667043 -0.441754
# 3      -0.487059  0.587379 -2.897320 -0.667043  0.212345
# 4      -0.487059  0.587379 -1.709444 -0.667043 -0.441754
# ...          ...       ...       ...       ...       ...
# 199730  0.093360  2.312394 -0.104915  1.850308  0.655533
# 199731  0.083440  2.187022 -0.104915  1.850308  0.991156
# 199732 -1.567601  0.106218 -0.062701  1.776268  0.212345
# 199733 -1.580545  0.053814 -0.062701  1.776268  1.682041
# 199734  0.726384  2.499705 -2.727521  1.776268  0.655533
#
# [199735 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# test and train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Decision Tree Regressor
dtr = DecisionTreeRegressor()

# hyperparameters
param_grid = {
    'max_depth': [2, 5, 10, 15, 20, 22],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20],
    'max_features': ['auto', 'sqrt', 'log2']
}

# gridsearchcv
grid_search = GridSearchCV(estimator=dtr, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# evalution metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(" ")
print('Mean squared error:', mse)
print('Mean Absolute Error', mae)
print('Root Mean squared error:', rmse)
print(" ")
print('R-squared:', r2)
# Out:
# Best hyperparameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 9, 'min_samples_split': 5}
#
# Mean squared error: 0.015026608910041416
# Mean Absolute Error 0.09677052462175917
# Root Mean squared error: 0.1225830694265787
#
# R-squared: 0.8633653077758398

# %%
new_sample = np.array([[8740, 999, np.log(44), 55, np.log(11)]])
new_sample = scaler.transform(new_sample[:, :5])
new_pred = best_model.predict(new_sample)[0]
np.exp(new_pred)
# Out:
# 228780.31448160167

# %%
# Saving the model
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(best_model, file)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
